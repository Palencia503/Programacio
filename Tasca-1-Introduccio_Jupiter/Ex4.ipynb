# %% [markdown]
# ## **Exercici 4** ##
#
# **Para descargarlo como html y pdf primero ejecute:**
#
# ![image.png](attachment:image.png)
#
# **Despues se abrio de forma visual en el navegador:**
#
# ![image-2.png](attachment:image-2.png)
#
# **Para descargarlo en html o otros formatos tienes que ir a *file* despues a *Save And* *Export Notebook As* y seleccionas el formato:**
#
# ![image-3.png](attachment:image-3.png)

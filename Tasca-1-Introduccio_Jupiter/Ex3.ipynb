# %% [markdown]
# *Repository GitHub:*
# https://github.com/Palencia503/Programacio.git

# %% [markdown]
# ## **Exercici 3** ##
#
# **Titulos:**
# ###### Hallo Jupyter
# ##### Hallo Jupyter
# #### Hallo Jupyter
# ### Hallo Jupyter
# ## Hallo Jupyter
# # Hallo Jupyter
# **Lista:**
# * Hallo Jupyter
# * Hallo Jupyter
# * Hallo Jupyter
#
# **Cambiar estilos de las letras:**
#
# **Hallo World**
#
# *Hallo World*
#
# **Imagen:**
#
# ![image.png](attachment:image.png)
